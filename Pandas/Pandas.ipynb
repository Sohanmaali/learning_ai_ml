# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name": ["sohan", "raj", "rajesh", "mukesh", "anita", "deepak", "priya", "karan"],
    "markd": [95, 35, 63, 85, 78, 92, 56, 88],
    "city": ["Indore", "Bhopal", "Ujjain", "Agra", "Delhi", "Pune", "Jaipur", "Surat"],
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  markd    city
# 0   sohan     95  Indore
# 1     raj     35  Bhopal
# 2  rajesh     63  Ujjain
# 3  mukesh     85    Agra
# 4   anita     78   Delhi
# 5  deepak     92    Pune
# 6   priya     56  Jaipur
# 7   karan     88   Surat

# %%
# df.to_csv('friends.csv', index=False)

# %%
df.head(2)
# Out:
#     name  markd    city
# 0  sohan     95  Indore
# 1    raj     35  Bhopal

# %%
df.tail(2)
# Out:
#     name  markd    city
# 6  priya     56  Jaipur
# 7  karan     88   Surat

# %%
df.tail()
# Out:
#      name  markd    city
# 3  mukesh     85    Agra
# 4   anita     78   Delhi
# 5  deepak     92    Pune
# 6   priya     56  Jaipur
# 7   karan     88   Surat

# %%
df.describe()
# Out:
#            markd
# count   8.000000
# mean   74.000000
# std    20.921622
# min    35.000000
# 25%    61.250000
# 50%    81.500000
# 75%    89.000000
# max    95.000000

# %%
file = pd.read_csv("myfile.csv")

# %%
file['speed']
# Out:
# 0    100.0
# 1     35.0
# 2     63.0
# 3     85.0
# 4     69.0
# 5     68.8
# 6     68.6
# 7     68.4
# 8     68.2
# 9     68.0
# Name: speed, dtype: float64

# %%
file['speed'][0]=100
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_980\1028782362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['speed'][0]=100

# %%
# file.to_csv("myfile.csv",index=False)

# %%
# ser = pd.Series(np.random.rand(34))

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 333
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       334 non-null    float64
#  1   1       334 non-null    float64
#  2   2       334 non-null    float64
#  3   3       334 non-null    float64
#  4   4       334 non-null    float64
# dtypes: float64(5)
# memory usage: 15.7 KB

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.size
# Out:
# 1670

# %%
newdf.shape
# Out:
# (334, 5)

# %%
newdf.ndim
# Out:
# 2

# %%
newdf.unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_980\3437331028.py in ?()
# ----> 1 newdf.unique
#
# ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
