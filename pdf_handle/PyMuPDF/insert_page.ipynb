# %%
import fitz

first = fitz.open("../1.pdf")
second = fitz.open("../2.pdf")
new_pdf = fitz.open()
new_pdf.insert_pdf(first)
new_pdf.insert_pdf(second)
new_pdf.save("marged_pdf.pdf")
first.close()
second.close()
new_pdf.close()
