# %%
import pdfplumber as pdfp
import pandas as pd

# %%
pdf = pdfp.open("../3.pdf")

page = pdf.pages[0]
text = page.to_image()
# print(text)
text.show()

# %%
 for image in page.images:
        print(image)
# Out:
# {'x0': 56.6929, 'y0': 415.5285, 'x1': 538.5826999999999, 'y1': 664.8299, 'width': 481.8897999999999, 'height': 249.30139999999994, 'name': 'I1', 'stream': <PDFStream(22): raw=630765, {'Length': 630765, 'Filter': /'DCTDecode', 'Type': /'XObject', 'Subtype': /'Image', 'Width': 2768, 'Height': 1432, 'BitsPerComponent': 8, 'ColorSpace': [/'ICCBased', <PDFObjRef:16>]}>, 'srcsize': (2768, 1432), 'imagemask': None, 'bits': 8, 'colorspace': [/'ICCBased', <PDFStream(16): raw=2577, {'Length': <PDFObjRef:17>, 'Filter': /'FlateDecode', 'N': 3}>], 'mcid': None, 'tag': None, 'object_type': 'image', 'page_number': 1, 'top': 177.05990000000008, 'bottom': 426.3613, 'doctop': 177.05990000000008}
