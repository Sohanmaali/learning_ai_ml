# %%
import cv2
import pytesseract
all_attrs = dir(pytesseract)
callable_methods = [attr for attr in all_attrs if callable(getattr(pytesseract, attr))]
print(len(callable_methods))

for method in callable_methods:
    print(method)
